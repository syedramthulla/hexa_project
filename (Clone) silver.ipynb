# %%
from pyspark.sql.functions import *


df=spark.read.format("csv").option("header","true").option("inferSchema","true").load("path_to_path")
display(df)
df=spark.read.format("parquet").load("path_to_file")
display(df)
df=spark.read.json("Path")
display(df)
df=spark.read.format("delta").load("path")
display(df)
