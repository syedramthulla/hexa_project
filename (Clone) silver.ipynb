# %%
from pyspark.sql.functions import *

df=spark.read.option("header","true").option("inferSchema","true").csv("/Volumes/workspace/default/volume-1/cart_items.csv")
df_trans=df.dropDuplicates()\
            1.dropna(subset=["store_id"])\
            .fillna(0,subset=["cart_item_id"])
df_trans.write.format("delta").mode("overwrite").save("/Volumes/deltalakesyed/default/volumes/delta_table1")

# %%
df=spark.read.option("header","true").option("inferSchema","true").csv("/Volumes/workspace/default/volume-1/cart_items.csv")
display(df)

# %%
from delta.tables import *

DeltaTable.createIfNotExists(spark)\
    .tableName("")
