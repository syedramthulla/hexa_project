# %%
# %sql
INSERT INTO deltalakesyed.default.secondtable
VALUES (1,1000),(2,2000),(2,3000)

# %%
from delta.tables import DeltaTable

DeltaTable.createIfNotExists(spark) \
  .tableName("volumes/deltalakesyed.default.volumes.thirdtable") \
  .addColumn("id", "int") \
  .addColumn("salary", "int") \
  .execute()

# %%
datadf.write.format("delta").save("/Volumes/deltalakesyed/default/volumes/deltavol/")

# %%
# %sql
select * from deltalakesyed.default.secondtable

# %%
# %sql
from delta.tables import DeltaTable

create delta.table deltalakesyed.default.employee

# %%
# %sql
INSERT INTO deltalakesyed.default.secondtable
VALUES
(2,30),
(3,28);

# %%
# %sql
INSERT INTO deltalakesyed.default.firsttable
VALUES
(2,30),
(3,28),
(1,10);

# %%
df = spark.table("deltalakesyed.default.firsttable")
display(df)

# %%
df = spark.table("deltalakesyed.default.firsttable")
display(df)

# %%
# %sql
CREATE TABLE delatalakesyed.default.employee
(
  id  INT,
  salary  INT
)
